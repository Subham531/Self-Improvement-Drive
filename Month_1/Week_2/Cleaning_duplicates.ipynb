# %% [markdown]
# # 2nd day of 2nd week

# %%
import pandas as pd

df = pd.read_csv('OnlineOrders_of_a_ecommerce_website.csv')
df
# Out:
#                 crawl_timestamp  \
# 0     2016-03-25 22:59:23+00:00
# 1     2016-03-25 22:59:23+00:00
# 2     2016-03-25 22:59:23+00:00
# 3     2016-03-25 22:59:23+00:00
# 4     2016-03-25 22:59:23+00:00
# ...                         ...
# 8078  2016-03-05 12:31:04+00:00
# 8079  2016-03-05 12:31:04+00:00
# 8080  2016-03-05 12:31:04+00:00
# 8081  2016-03-05 12:31:04+00:00
# 8082  2016-03-05 12:31:04+00:00
#
#                                            product_name  \
# 0                   Alisha Solid Women's Cycling Shorts
# 1                   FabHomeDecor Fabric Double Sofa Bed
# 2                                            AW Bellies
# 3                   Alisha Solid Women's Cycling Shorts
# 4                 Sicons All Purpose Arnica Dog Shampoo
# ...                                                 ...
# 8078  Sinina Chanderi Embroidered Salwar Suit Dupatt...
# 8079  Aarushi Fashion Chanderi Embroidered Salwar Su...
# 8080  Ambika Lahenga Embroidered Lehenga, Choli and ...
# ...

# %%
df['brand'].nunique()
# Out:
# 2587

# %%
df.isna().sum()
# Out:
# crawl_timestamp          0
# product_name             0
# product_category_tree    0
# retail_price             0
# discounted_price         0
# brand                    0
# dtype: int64

# %%
df['product_category_tree'][0]
# Out:
# '["Clothing >> Women\'s Clothing >> Lingerie, Sleep & Swimwear >> Shorts >> Alisha Shorts >> Alisha Solid Women\'s Cycling Shorts"]'

# %%
import re
# re.sub(r'[^a-zA-Z ]','',df['product_category_tree'][i])
# for i in range(df)
df['product_category_tree'] = (
    df['product_category_tree']
    .str.lower()
    .str.strip()
    .str.replace(r'[^a-zA-Z ]','',regex=True)
)

# %%
df['product_category_tree']
# Out:
# 0       clothing  womens clothing  lingerie sleep  swi...
# 1       furniture  living room furniture  sofa beds  f...
# 2       footwear  womens footwear  ballerinas  aw bellies
# 3       clothing  womens clothing  lingerie sleep  swi...
# 4       pet supplies  grooming  skin  coat care  shamp...
#                               ...
# 8078    clothing  womens clothing  ethnic wear  fabric...
# 8079    clothing  womens clothing  ethnic wear  fabric...
# 8080    clothing  womens clothing  ethnic wear  leheng...
# 8081    clothing  womens clothing  ethnic wear  fabric...
# 8082    clothing  womens clothing  ethnic wear  fabric...
# Name: product_category_tree, Length: 8083, dtype: object

# %% [markdown]
# # 3rd day of the 2nd Week

# %%
type(df['crawl_timestamp'][0])
# Out:
# str

# %%
df['crawl_timestamp'] = pd.to_datetime(df['crawl_timestamp'],errors='coerce')
print(df['crawl_timestamp'].dtype)
# Out:
# datetime64[ns]

# %%
df['crawl_timestamp'] = df['crawl_timestamp'].dt.date
df['crawl_timestamp']
# Out:
# 0       2016-03-25
# 1       2016-03-25
# 2       2016-03-25
# 3       2016-03-25
# 4       2016-03-25
#            ...
# 6716    2016-03-05
# 6717    2016-03-05
# 6718    2016-03-05
# 6719    2016-03-05
# 6720    2016-03-05
# Name: crawl_timestamp, Length: 6721, dtype: object

# %%
df.shape
# Out:
# (6721, 9)

# %%
df.drop_duplicates(inplace=True,ignore_index=True)

# %%
df.shape
# Out:
# (6721, 9)

# %%
df['year'] = df['crawl_timestamp'].dt.year
df['year']
# Out:
# 0       2016
# 1       2016
# 2       2016
# 3       2016
# 4       2016
#         ...
# 6716    2016
# 6717    2016
# 6718    2016
# 6719    2016
# 6720    2016
# Name: year, Length: 6721, dtype: int64

# %%
df['Month'] = df['crawl_timestamp'].dt.month
df['Month']
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 6716    3
# 6717    3
# 6718    3
# 6719    3
# 6720    3
# Name: Month, Length: 6721, dtype: int64

# %%
df['Day'] = df['crawl_timestamp'].dt.day
df['Day']
# Out:
# 0       25
# 1       25
# 2       25
# 3       25
# 4       25
#         ..
# 6716     5
# 6717     5
# 6718     5
# 6719     5
# 6720     5
# Name: Day, Length: 6721, dtype: int64

# %%
type(df['product_name'][0])
# Out:
# str

# %%
df['product_name'] = df['product_name'].astype(str)

# %%
df['product_name'].astype(str)
# Out:
# 0                     Alisha Solid Women's Cycling Shorts
# 1                     FabHomeDecor Fabric Double Sofa Bed
# 2                                              AW Bellies
# 3                     Alisha Solid Women's Cycling Shorts
# 4                   Sicons All Purpose Arnica Dog Shampoo
#                               ...
# 6716    Sinina Chanderi Embroidered Salwar Suit Dupatt...
# 6717    Aarushi Fashion Chanderi Embroidered Salwar Su...
# 6718    Ambika Lahenga Embroidered Lehenga, Choli and ...
# 6719    Sinina Chanderi Embroidered Salwar Suit Dupatt...
# 6720    Aarushi Fashion Silk Striped Salwar Suit Dupat...
# Name: product_name, Length: 6721, dtype: object
